# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
df.columns=df.columns.str.lower()
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
df.set_index('linename')
# Out:
#             c/a  unit       scp        station division        date      time  \
# linename
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  16:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  20:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  16:00:00
# ...

# %% [markdown]
# ## Painstakingly change the index back

# %%
a = list(range(len(df)))
len(a)
#df.reset_index(inplace=True)
#df
#df.drop('index', axis =1, inplace = True )
#df.drop('level_0', axis =1, inplace = True )
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
df.station.unique()
# Out:
# array(['59 ST', '5 AV/59 ST', '57 ST-7 AV', '49 ST', 'TIMES SQ-42 ST',
#        '34 ST-HERALD SQ', '28 ST', '23 ST', '14 ST-UNION SQ', '8 ST-NYU',
#        'PRINCE ST', 'CANAL ST', 'CITY HALL', 'CORTLANDT ST', 'RECTOR ST',
#        'WHITEHALL S-FRY', 'DELANCEY/ESSEX', 'BOWERY', 'CHAMBERS ST',
#        'FULTON ST', 'BROAD ST', '7 AV', 'PARK PLACE', 'BOTANIC GARDEN',
#        'PROSPECT PARK', 'PARKSIDE AV', 'CHURCH AV', 'BEVERLEY ROAD',
#        'CORTELYOU RD', 'NEWKIRK PLAZA', 'AVENUE H', 'AVENUE J',
#        'AVENUE M', 'KINGS HWY', 'AVENUE U', 'NECK RD', 'SHEEPSHEAD BAY',
#        'BRIGHTON BEACH', 'OCEAN PKWY', 'BOROUGH HALL', 'JAY ST-METROTEC',
#        'DEKALB AV', 'ATL AV-BARCLAY', 'UNION ST', '4AV-9 ST',
#        'PROSPECT AV', '25 ST', '36 ST', '45 ST', '53 ST', 'BAY RIDGE AV',
#        '77 ST', '86 ST', 'BAY RIDGE-95 ST', '8 AV', 'FT HAMILTON PKY',
#        'NEW UTRECHT AV', '18 AV', '20 AV', 'BAY PKWY', '9 AV', '50 ST',
# ...

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
df['Num_lines'] = df.linename.map(lambda x: len(x))
#df['Num_lines']
#df['linename']

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.lower()
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               ',
#        'num_lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
import datetime

# %%
df.date = pd.to_datetime(df.date)
type(df.date[1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['dayoweek'] = df['date'].dt.dayofweek

df.dayoweek
df.head()
print(min(df.date),max(df.date))
#df.columns
# Out:
# 2018-08-25 00:00:00 2018-08-31 00:00:00

# %%
def dow_num_to_day(num, col):
    if (num[col] > 6).any():
        return print('no such day')
    day_list = ['a_mon','b_tues','c_weds','d_thurs','e_fri','f_sat','g_sun']
    num['day_text'] = num[col].map(lambda x: day_list[x])
    return num['day_text']
    #n_list=list(range(0,7,1))
    #daytups = zip(n_list,day_list)

# %%
#df.head()
dow_num_to_day(df, 'dayoweek')

# %%
vcs = dict(df.day_text.value_counts())
sorted(vcs.keys())
# Out:
# ['a_mon', 'b_tues', 'c_weds', 'd_thurs', 'e_fri', 'f_sat', 'g_sun']

# %%
plt.figure(figsize=(10,6))
plt.bar(x = vcs.keys(), height = vcs.values(), label = 'I LOVE LAMP')
plt.xlabel('Day')
plt.ylabel('rides volume')
plt.show()

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes

# %%
sum(vcs[a_mon],)

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
